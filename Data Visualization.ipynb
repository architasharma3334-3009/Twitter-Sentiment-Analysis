# %% [markdown]
# <h2>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# Screenshots of Data Visualisation
# </span>
# </h2>
# This section presents the visualizations created during the analysis process. These visualizations help in understanding the distribution of sentiments, frequent words in tweets, and model performance in sentiment classification.
#
#
# <h2>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# Included Visualisation
# </span>
# </h2>
#
# - Sentiment Distribution Plot – Shows the number of positive and negative tweets in the dataset.
#
# - Word Cloud for Positive Tweets – Displays the most frequently occurring words in positive tweets.
#
# - Word Cloud for Negative Tweets – Highlights the most common words appearing in negative tweets.
#
# - Model Accuracy Comparison Bar Chart – Compares the accuracy of different machine learning models used for sentiment classification.
#
# - Confusion Matrix Visualization – Shows the performance of the classification model by displaying correct and incorrect predictions.

# %% [markdown]
# <h2>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# Import Libraries
# </span>
# </h2>

# %%
# data handling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# Load Dataset
# </span>
# </h2>

# %%
# here we create a list of our column name 
columns_name = ["target","id","date","flag","user","text"]

# here we give a column name that is given in columns_name 

df = pd.read_csv(r"training.1600000.processed.noemoticon.csv",
                 names=columns_name,encoding="ISO-8859-1")
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# <h3>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# 1. Sentiment Distribution Plot
# </span>
# </h3>

# %% [markdown]
# ![image.png](attachment:185becb7-52f5-424a-b260-11c2dc836ebb.png)

# %% [markdown]
# ##### Target Variable Details :
#
# The target column represents the sentiment of tweets in the dataset.
#
# 0 → Negative sentiment
#
# 4 → Positive sentiment
#
# This column is used as the output variable for training the sentiment analysis model.
#
# ##### Summary :
#
# The Exploratory Data Analysis shows that the dataset contains a large number of tweets with clearly defined sentiment labels. The dataset does not contain missing values and provides a balanced distribution of positive and negative tweets. This makes it suitable for building a machine learning model for sentiment classification.

# %% [markdown]
# <h3>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# 2. Word Cloud for Positive Tweets
# </span>
# </h3>

# %% [markdown]
# ![image.png](attachment:83e25f60-7c06-4330-99e0-da57d4002dfe.png)

# %% [markdown]
# ###### Summary ->
#
# This word cloud visualization represents the most commonly used words in tweets with positive sentiment. Words that appear more frequently in positive tweets are displayed in larger font sizes, while less frequent words appear smaller. This visualization helps identify the common vocabulary used when users express positive opinions or experiences in their tweets.

# %% [markdown]
# <h3>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# 3. Word Cloud for Negative Tweets
# </span>
# </h3>

# %% [markdown]
# ![image.png](attachment:7734cd32-ad6f-42ec-894d-cd126bb05e61.png)

# %% [markdown]
# ###### Summary ->
#
# This visualization displays the most frequently occurring words in tweets with negative sentiment. The word cloud highlights the terms that appear most often in negative tweets by increasing their font size. Larger words indicate higher frequency, while smaller words represent less common terms. This helps identify patterns and commonly used expressions associated with negative opinions in the dataset.

# %% [markdown]
# <h3>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# 4. Model Accuracy Comparison Bar Chart
# </span>
# </h3>

# %% [markdown]
# ![image.png](attachment:e8d3b0d4-f1c5-40f3-944d-aab4038faeeb.png)

# %% [markdown]
# ###### Summary ->
#
# This bar chart compares the accuracy scores of different machine learning models used for tweet sentiment classification. It visually highlights the performance differences among the models.

# %% [markdown]
# <h3>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# 5.  Confusion Matrix Visualization
# </span>
# </h3>

# %% [markdown]
# ![image.png](attachment:19cae376-275b-4813-816e-534db1daa896.png)

# %% [markdown]
# ###### Summary ->
#
# This code generates a confusion matrix to evaluate the performance of the Support Vector Machine (SVM) model. It visualizes the number of correct and incorrect predictions made by the model. The heatmap helps in understanding how well the model classifies positive and negative tweet sentiments.

# %% [markdown]
# <h2>
# <span style="background-color:#EAEAEA; padding:6px; border-radius:4px;">
# Final Summary of Data Visualization
# </span>
# </h2>
#
# The visualizations helped in understanding the dataset and sentiment patterns more clearly. The sentiment distribution plot showed the balance between positive and negative tweets, while word clouds highlighted the most frequent words in each sentiment category. The confusion matrix and accuracy comparison chart helped evaluate the performance of different machine learning models and identify the best performing model.
